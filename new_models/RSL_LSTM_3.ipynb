# %% [markdown]
# # 1. Improt  and Install Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import  mediapipe  as mp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras import regularizers

# %% [markdown]
# # 2. Keypoint using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic Model
mp_drawing  = mp.solutions.drawing_utils # Drawing utilities

# %%
def  mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB) #converting color
    image.flags.writeable = False # Image is no longer writeable
    results = model.process(image) #make prediction
    image.flags.writeable = True # Image is now writeable
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #converting color
    return image,results

# %% [markdown]
# # This is optional now,The one being used is the draw_styled_landmarks.

# %%
def draw_styled_landmarks(image, result):
    mp_drawing.draw_landmarks(image,result.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(250,250,250), thickness = 2, circle_radius = 2),
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness = 1, circle_radius = 1)) # Draw pose conections
    mp_drawing.draw_landmarks(image,result.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS) # Draw left Hand conections
    mp_drawing.draw_landmarks(image,result.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS) # Draw Right Hand conection.

# %% [markdown]
# # Optional {For testing the camera and detection mechanisim}

# %%
# cap  = cv2.VideoCapture(1)
# # Accessing mediapipe model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence = 0.5) as holistic:
#     while cap.isOpened():
        
#         # Read feed
#         ret,frame = cap.read()

#         # Make detection
#         image, results = mediapipe_detection(frame,holistic)
        
        
#         # Draw  landmarks
#         draw_styled_landmarks(image,results)
        

#         cv2.imshow('RSL Feed', image)
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
# With out Face points  multiple left and hand cordinates to increase accuracy
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    # magnifiying the hands value for better accuracy
    return np.concatenate([pose, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Output will be  arrray containing numerical values for the extracted keypoints
# Path to outr external data
DATA_PATH = os.path.join('..', 'signlang-kinyarwanda/Data')  # Adjust path as needed


# Check if the folder exists
if os.path.isdir(DATA_PATH):
    print("Folder exists:", DATA_PATH)
else:
    print("Folder NOT found:", DATA_PATH)
# Out:
# Folder exists: ..\signlang-kinyarwanda/Data

# %%
# Get all action folders from the external dataset
action_folders = [f for f in os.listdir(DATA_PATH) if os.path.isdir(os.path.join(DATA_PATH, f))]
actions = np.array(sorted(action_folders))  # Sort for consistency

print(f"Found {len(actions)} actions in the dataset:")
print(actions)
# Out:
# Found 15 actions in the dataset:
# ['---' 'akarere' 'akazi' 'amakuru' 'bayi' 'bibi' 'igihugu' 'neza'
#  'nyarugenge' 'oya' 'papa' 'umujyi wa kigali' 'umurenge' 'urakoze' 'yego']

# %%
# Auto-detect number of sequences and frames
sample_action = actions[0]
sample_path = os.path.join(DATA_PATH, sample_action)
sequences_in_action = [d for d in os.listdir(sample_path) if os.path.isdir(os.path.join(sample_path, d))]
no_sequences = len(sequences_in_action)

# Check frames in first sequence
first_sequence_path = os.path.join(sample_path, sequences_in_action[0])
npy_files = [f for f in os.listdir(first_sequence_path) if f.endswith('.npy')]
sequence_length = len(npy_files)

print(f"\nDataset Info:")
print(f"- Number of sequences per action: {no_sequences}")
print(f"- Frames per sequence: {sequence_length}")

print(" Now we have a total of {} videos from all actions.".format(len(actions)*no_sequences))
# Out:
# Dataset Info:
# - Number of sequences per action: 40
# - Frames per sequence: 30
#  Now we have a total of 600 videos from all actions.

# %%
# Inspect the data structure
import glob

print("=" * 60)
print("DATA STRUCTURE INSPECTION")
print("=" * 60)

for action in actions[:3]:  # Check first 3 actions
    action_path = os.path.join(DATA_PATH, action)
    sequences = sorted([d for d in os.listdir(action_path) if os.path.isdir(os.path.join(action_path, d))])
    
    print(f"\nAction: {action}")
    print(f"  Total sequences: {len(sequences)}")
    
    # Check first sequence
    if sequences:
        first_seq_path = os.path.join(action_path, sequences[0])
        npy_files = sorted([f for f in os.listdir(first_seq_path) if f.endswith('.npy')])
        
        print(f"  First sequence: {sequences[0]}")
        print(f"    Number of .npy files: {len(npy_files)}")
        
        # Load one file to check shape
        if npy_files:
            sample_file = os.path.join(first_seq_path, npy_files[0])
            sample_data = np.load(sample_file)
            print(f"    Sample file shape: {sample_data.shape}")
            print(f"    Feature dimensions: {sample_data.shape[0] if len(sample_data.shape) == 1 else sample_data.shape}")

print("\n" + "=" * 60)
# Out:
# ============================================================
# DATA STRUCTURE INSPECTION
# ============================================================
#
# Action: ---
#   Total sequences: 40
#   First sequence: 1
#     Number of .npy files: 30
#     Sample file shape: (1518,)
#     Feature dimensions: 1518
#
# Action: akarere
#   Total sequences: 40
#   First sequence: 1
#     Number of .npy files: 30
#     Sample file shape: (1518,)
#     Feature dimensions: 1518
#
# Action: akazi
#   Total sequences: 40
#   First sequence: 1
#     Number of .npy files: 30
#     Sample file shape: (1518,)
#     Feature dimensions: 1518
#
# ============================================================

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %% [markdown]
# # SKIPPED
# **Note:** Data collection is skipped because we're using pre-existing `.npy` files from the external dataset.

# %% [markdown]
# # 6. Preprocess External Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
# Create label map
label_map = {label: num for num, label in enumerate(actions)}
print("Label Mapping:")
for label, num in label_map.items():
    print(f"  {num}: {label}")

# Load sequences and labels
sequences, labels = [], []
missing_data = []
padded_sequences = []
truncated_sequences = []

print("\nLoading data...")
for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    
    # Get all sequence folders
    sequence_folders = sorted([d for d in os.listdir(action_path) 
                               if os.path.isdir(os.path.join(action_path, d))])
    
    for sequence_folder in sequence_folders:
        sequence_path = os.path.join(action_path, sequence_folder)
        window = []
        
        try:
            # Get all .npy files in sequence
            npy_files = sorted([f for f in os.listdir(sequence_path) if f.endswith('.npy')])
            
            # Check if sequence length matches
            actual_length = len(npy_files)
            
            # Load each frame
            for npy_file in npy_files:
                npy_path = os.path.join(sequence_path, npy_file)
                res = np.load(npy_path)
                window.append(res)
            
            # Handle different sequence lengths
            if actual_length < sequence_length:
                # PAD: Add zero frames to match sequence_length
                feature_dim = len(window[0])
                padding_needed = sequence_length - actual_length
                for _ in range(padding_needed):
                    window.append(np.zeros(feature_dim))
                padded_sequences.append(f"{action}/{sequence_folder} - Padded {padding_needed} frames")
                
            elif actual_length > sequence_length:
                # TRUNCATE: Keep only first sequence_length frames
                window = window[:sequence_length]
                truncated_sequences.append(f"{action}/{sequence_folder} - Truncated from {actual_length} to {sequence_length}")
            
            # Add to sequences (all data included now)
            sequences.append(window)
            labels.append(label_map[action])
            
        except Exception as e:
            missing_data.append(f"{action}/{sequence_folder} - Error: {str(e)}")
            continue

print(f"\n{'='*60}")
print(f"DATA LOADING SUMMARY")
print(f"{'='*60}")
print(f"✓ Loaded {len(sequences)} sequences successfully")
print(f"  - Padded sequences: {len(padded_sequences)}")
print(f"  - Truncated sequences: {len(truncated_sequences)}")
print(f"  - Failed sequences: {len(missing_data)}")

if padded_sequences:
    print(f"\nPadded Sequences (first 5):")
    for item in padded_sequences[:5]:
        print(f"  • {item}")
    if len(padded_sequences) > 5:
        print(f"  ... and {len(padded_sequences) - 5} more")

if truncated_sequences:
    print(f"\nTruncated Sequences (first 5):")
    for item in truncated_sequences[:5]:
        print(f"  • {item}")
    if len(truncated_sequences) > 5:
        print(f"  ... and {len(truncated_sequences) - 5} more")

if missing_data:
    print(f"\n⚠️ Failed to Load ({len(missing_data)} sequences):")
    for item in missing_data[:10]:
        print(f"  ✗ {item}")
    if len(missing_data) > 10:
        print(f"  ... and {len(missing_data) - 10} more")

print(f"\n{'='*60}")
# Out:
# Label Mapping:
#   0: ---
#   1: akarere
#   2: akazi
#   3: amakuru
#   4: bayi
#   5: bibi
#   6: igihugu
#   7: neza
#   8: nyarugenge
#   9: oya
#   10: papa
#   11: umujyi wa kigali
#   12: umurenge
#   13: urakoze
#   14: yego
#
# Loading data...
#
# ============================================================
# DATA LOADING SUMMARY
# ============================================================
# ✓ Loaded 600 sequences successfully
#   - Padded sequences: 0
#   - Truncated sequences: 249
#   - Failed sequences: 0
#
# Truncated Sequences (first 5):
#   • nyarugenge/1 - Truncated from 60 to 30
#   • nyarugenge/10 - Truncated from 60 to 30
#   • nyarugenge/11 - Truncated from 60 to 30
#   • nyarugenge/12 - Truncated from 60 to 30
#   • nyarugenge/13 - Truncated from 60 to 30
#   ... and 244 more
#
# ============================================================

# %%
# Verify loaded data
print("\nData Shapes:")
print(f"Sequences array shape: {np.array(sequences).shape}")
print(f"Labels array shape: {np.array(labels).shape}")

# Check feature dimensions
if len(sequences) > 0:
    print(f"\nFeature dimensions per frame: {len(sequences[0][0])}")
    print(f"Expected: 1392 (Phase 3 with magnified hands)")
    
    # Distribution of labels
    unique_labels, counts = np.unique(labels, return_counts=True)
    print("\nLabel Distribution:")
    for label_idx, count in zip(unique_labels, counts):
        action_name = actions[label_idx]
        print(f"  {action_name}: {count} sequences")
# Out:
# Data Shapes:
# Sequences array shape: (600, 30, 1518)
# Labels array shape: (600,)
#
# Feature dimensions per frame: 1518
# Expected: 1392 (Phase 3 with magnified hands)
#
# Label Distribution:
#   ---: 40 sequences
#   akarere: 40 sequences
#   akazi: 40 sequences
#   amakuru: 40 sequences
#   bayi: 40 sequences
#   bibi: 40 sequences
#   igihugu: 40 sequences
#   neza: 40 sequences
#   nyarugenge: 40 sequences
#   oya: 40 sequences
#   papa: 40 sequences
#   umujyi wa kigali: 40 sequences
#   umurenge: 40 sequences
#   urakoze: 40 sequences
#   yego: 40 sequences

# %% [markdown]
# # 7. Convert to arrays and split

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

print(f"\nFinal shapes:")
print(f"X (features): {X.shape}")  # Should be (num_sequences, 30, feature_dim)
print(f"y (labels): {y.shape}")    # Should be (num_sequences, num_actions)

# Get actual feature dimensions
actual_feature_dim = X.shape[2]
print(f"\nActual feature dimensions: {actual_feature_dim}")
# Out:
# Final shapes:
# X (features): (600, 30, 1518)
# y (labels): (600, 15)
#
# Actual feature dimensions: 1518

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=labels)

print(f"\nTrain-Test Split:")
print(f"Training samples: {X_train.shape[0]}")
print(f"Testing samples: {X_test.shape[0]}")
# Out:
# Train-Test Split:
# Training samples: 420
# Testing samples: 180

# %% [markdown]
# # 8. Build Model with Correct Input Shape

# %%
# Setup callbacks
log_dir = os.path.join('Logs_External_Data')
tb_callback = TensorBoard(log_dir=log_dir)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Optimizer
opt = Adam(learning_rate=0.00001)

# Model architecture - UPDATE INPUT SHAPE
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu',
               kernel_regularizer=regularizers.l2(0.01), 
               input_shape=(sequence_length, actual_feature_dim)))  # Use actual dimensions
model.add(LSTM(128, return_sequences=True, activation='relu', 
               kernel_regularizer=regularizers.l2(0.01)))
model.add(LSTM(64, return_sequences=False, activation='relu', 
               kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(len(actions), activation='softmax', kernel_regularizer=regularizers.l2(0.01)))
# Out:
# C:\Users\STUDENT\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# Summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 30, 64)         │       405,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 15)             │           495 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 560,207 (2.14 MB)
#  Trainable params: 560,207 (2.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 9. Train the model

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200,
    validation_data=(X_test, y_test),  # Use test set for validation
    callbacks=[tb_callback, early_stop],
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - categorical_accuracy: 0.0744 - loss: 11.1925 - val_categorical_accuracy: 0.0944 - val_loss: 11.1546
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - categorical_accuracy: 0.0794 - loss: 11.1482 - val_categorical_accuracy: 0.1000 - val_loss: 11.1113
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.0784 - loss: 11.1075 - val_categorical_accuracy: 0.1056 - val_loss: 11.0686
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - categorical_accuracy: 0.0877 - loss: 11.0626 - val_categorical_accuracy: 0.1056 - val_loss: 11.0256
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - categorical_accuracy: 0.0855 - loss: 11.0158 - val_categorical_accuracy: 0.0667 - val_loss: 10.9815
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - categorical_accuracy: 0.0492 - loss: 10.9771 - val_categorical_accuracy: 0.0667 - val_loss: 10.9340
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - categorical_accuracy: 0.0710 - loss: 10.9275 - val_categorical_accuracy: 0.0667 - val_loss: 10.8832
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - categorical_accuracy: 0.0924 - loss: 10.8733 - val_categorical_accuracy: 0.1111 - val_loss: 10.8190
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - categorical_accuracy: 0.1335 - loss: 10.8169 - val_categorical_accuracy: 0.1333 - val_loss: 10.7444
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - categorical_accuracy: 0.1482 - loss: 10.7625 - val_categorical_accuracy: 0.1722 - val_loss: 10.6728
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - categorical_accuracy: 0.1378 - loss: 10.7137 - val_categorical_accuracy: 0.1611 - val_loss: 10.6255
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - categorical_accuracy: 0.1694 - loss: 10.6553 - val_categorical_accuracy: 0.1667 - val_loss: 10.5770
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.1513 - loss: 10.6158 - val_categorical_accuracy: 0.1667 - val_loss: 10.5303
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.1520 - loss: 10.5639 - val_categorical_accuracy: 0.1833 - val_loss: 10.5007
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.1789 - loss: 10.4580 - val_categorical_accuracy: 0.2111 - val_loss: 10.4429
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - categorical_accuracy: 0.1668 - loss: 10.4672 - val_categorical_accuracy: 0.2056 - val_loss: 10.3880
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - categorical_accuracy: 0.2022 - loss: 10.3501 - val_categorical_accuracy: 0.2222 - val_loss: 10.3462
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.1794 - loss: 10.3386 - val_categorical_accuracy: 0.2000 - val_loss: 10.3003
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - categorical_accuracy: 0.1926 - loss: 10.2549 - val_categorical_accuracy: 0.2111 - val_loss: 10.2591
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - categorical_accuracy: 0.2177 - loss: 10.2093 - val_categorical_accuracy: 0.2389 - val_loss: 10.2154
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - categorical_accuracy: 0.2366 - loss: 10.1822 - val_categorical_accuracy: 0.2389 - val_loss: 10.1698
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - categorical_accuracy: 0.2350 - loss: 10.0975 - val_categorical_accuracy: 0.2278 - val_loss: 10.1359
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - categorical_accuracy: 0.1887 - loss: 10.0957 - val_categorical_accuracy: 0.2333 - val_loss: 10.1057
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.2420 - loss: 10.0477 - val_categorical_accuracy: 0.2222 - val_loss: 10.0561
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - categorical_accuracy: 0.2534 - loss: 9.9891 - val_categorical_accuracy: 0.2278 - val_loss: 10.0402
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.2334 - loss: 10.0031 - val_categorical_accuracy: 0.2556 - val_loss: 10.0150
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - categorical_accuracy: 0.2317 - loss: 9.9986 - val_categorical_accuracy: 0.2500 - val_loss: 9.9384
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - categorical_accuracy: 0.2219 - loss: 9.9326 - val_categorical_accuracy: 0.2611 - val_loss: 9.9169
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.2781 - loss: 9.8380 - val_categorical_accuracy: 0.2556 - val_loss: 9.8828
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.2905 - loss: 9.7894 - val_categorical_accuracy: 0.2667 - val_loss: 9.8519
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - categorical_accuracy: 0.2738 - loss: 9.7496 - val_categorical_accuracy: 0.2444 - val_loss: 9.8439
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - categorical_accuracy: 0.2686 - loss: 9.7557 - val_categorical_accuracy: 0.2611 - val_loss: 9.7931
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - categorical_accuracy: 0.3050 - loss: 9.6782 - val_categorical_accuracy: 0.2611 - val_loss: 9.7617
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.2926 - loss: 9.6641 - val_categorical_accuracy: 0.2722 - val_loss: 9.7427
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.3124 - loss: 9.6027 - val_categorical_accuracy: 0.2611 - val_loss: 9.6983
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.3042 - loss: 9.5755 - val_categorical_accuracy: 0.2778 - val_loss: 9.6473
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - categorical_accuracy: 0.2922 - loss: 9.5633 - val_categorical_accuracy: 0.2833 - val_loss: 9.6216
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.3141 - loss: 9.4896 - val_categorical_accuracy: 0.2889 - val_loss: 9.5896
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - categorical_accuracy: 0.3228 - loss: 9.4592 - val_categorical_accuracy: 0.3222 - val_loss: 9.5525
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - categorical_accuracy: 0.3601 - loss: 9.3485 - val_categorical_accuracy: 0.3111 - val_loss: 9.5065
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - categorical_accuracy: 0.3667 - loss: 9.2898 - val_categorical_accuracy: 0.3222 - val_loss: 9.4906
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - categorical_accuracy: 0.3371 - loss: 9.3799 - val_categorical_accuracy: 0.3556 - val_loss: 9.4432
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - categorical_accuracy: 0.3896 - loss: 9.3109 - val_categorical_accuracy: 0.4167 - val_loss: 9.3995
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - categorical_accuracy: 0.4308 - loss: 9.2634 - val_categorical_accuracy: 0.4278 - val_loss: 9.3721
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - categorical_accuracy: 0.4466 - loss: 9.1642 - val_categorical_accuracy: 0.4111 - val_loss: 9.3306
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - categorical_accuracy: 0.4897 - loss: 9.2318 - val_categorical_accuracy: 0.4611 - val_loss: 9.2921
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.4752 - loss: 9.1135 - val_categorical_accuracy: 0.4833 - val_loss: 9.2608
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.4736 - loss: 9.0803 - val_categorical_accuracy: 0.4778 - val_loss: 9.2670
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - categorical_accuracy: 0.4840 - loss: 9.0950 - val_categorical_accuracy: 0.4833 - val_loss: 9.1912
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - categorical_accuracy: 0.4909 - loss: 8.9690 - val_categorical_accuracy: 0.5000 - val_loss: 9.1786
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.4753 - loss: 9.0375 - val_categorical_accuracy: 0.5056 - val_loss: 9.1751
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - categorical_accuracy: 0.4946 - loss: 8.9825 - val_categorical_accuracy: 0.4889 - val_loss: 9.1406
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.4948 - loss: 8.9546 - val_categorical_accuracy: 0.5000 - val_loss: 9.0923
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - categorical_accuracy: 0.4867 - loss: 8.9211 - val_categorical_accuracy: 0.4944 - val_loss: 9.0422
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - categorical_accuracy: 0.5170 - loss: 8.8478 - val_categorical_accuracy: 0.4889 - val_loss: 9.0468
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - categorical_accuracy: 0.5071 - loss: 8.8517 - val_categorical_accuracy: 0.5111 - val_loss: 9.0350
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - categorical_accuracy: 0.5465 - loss: 8.7707 - val_categorical_accuracy: 0.5278 - val_loss: 8.9508
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - categorical_accuracy: 0.5149 - loss: 8.8200 - val_categorical_accuracy: 0.5222 - val_loss: 8.9557
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - categorical_accuracy: 0.5357 - loss: 8.7417 - val_categorical_accuracy: 0.5222 - val_loss: 8.9331
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - categorical_accuracy: 0.5414 - loss: 8.6338 - val_categorical_accuracy: 0.5333 - val_loss: 8.8864
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - categorical_accuracy: 0.5032 - loss: 8.6982 - val_categorical_accuracy: 0.5389 - val_loss: 8.8678
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - categorical_accuracy: 0.5383 - loss: 8.6345 - val_categorical_accuracy: 0.5333 - val_loss: 8.8430
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - categorical_accuracy: 0.5166 - loss: 8.6315 - val_categorical_accuracy: 0.5389 - val_loss: 8.8119
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - categorical_accuracy: 0.5429 - loss: 8.6407 - val_categorical_accuracy: 0.5333 - val_loss: 8.8039
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.5481 - loss: 8.6274 - val_categorical_accuracy: 0.5167 - val_loss: 8.8823
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.5290 - loss: 8.5886 - val_categorical_accuracy: 0.5222 - val_loss: 8.7741
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.5493 - loss: 8.5806 - val_categorical_accuracy: 0.5222 - val_loss: 8.7286
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - categorical_accuracy: 0.5410 - loss: 8.5001 - val_categorical_accuracy: 0.5444 - val_loss: 8.6795
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - categorical_accuracy: 0.5536 - loss: 8.4002 - val_categorical_accuracy: 0.5444 - val_loss: 8.6803
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - categorical_accuracy: 0.5419 - loss: 8.5330 - val_categorical_accuracy: 0.5500 - val_loss: 8.6077
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - categorical_accuracy: 0.6053 - loss: 8.3581 - val_categorical_accuracy: 0.5500 - val_loss: 8.5872
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - categorical_accuracy: 0.5720 - loss: 8.3142 - val_categorical_accuracy: 0.5556 - val_loss: 8.5764
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - categorical_accuracy: 0.5552 - loss: 8.3159 - val_categorical_accuracy: 0.5333 - val_loss: 8.5076
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.6011 - loss: 8.1878 - val_categorical_accuracy: 0.5500 - val_loss: 8.4662
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.5858 - loss: 8.1820 - val_categorical_accuracy: 0.5333 - val_loss: 8.4477
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - categorical_accuracy: 0.5993 - loss: 8.0666 - val_categorical_accuracy: 0.5611 - val_loss: 8.3399
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - categorical_accuracy: 0.6053 - loss: 8.0219 - val_categorical_accuracy: 0.5389 - val_loss: 8.3070
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - categorical_accuracy: 0.6286 - loss: 7.9463 - val_categorical_accuracy: 0.5667 - val_loss: 8.2566
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.5452 - loss: 8.0525 - val_categorical_accuracy: 0.5056 - val_loss: 8.2486
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - categorical_accuracy: 0.6057 - loss: 7.9009 - val_categorical_accuracy: 0.5389 - val_loss: 8.2725
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - categorical_accuracy: 0.6327 - loss: 7.8292 - val_categorical_accuracy: 0.5944 - val_loss: 8.1347
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - categorical_accuracy: 0.6247 - loss: 7.8733 - val_categorical_accuracy: 0.5722 - val_loss: 8.1786
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - categorical_accuracy: 0.6447 - loss: 7.8344 - val_categorical_accuracy: 0.5778 - val_loss: 8.2411
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - categorical_accuracy: 0.5491 - loss: 8.2117 - val_categorical_accuracy: 0.5722 - val_loss: 8.1616
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.6350 - loss: 7.8878 - val_categorical_accuracy: 0.5889 - val_loss: 8.0851
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - categorical_accuracy: 0.6425 - loss: 7.8148 - val_categorical_accuracy: 0.6056 - val_loss: 8.0482
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - categorical_accuracy: 0.6430 - loss: 7.7664 - val_categorical_accuracy: 0.6000 - val_loss: 7.9765
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - categorical_accuracy: 0.6525 - loss: 7.7018 - val_categorical_accuracy: 0.5833 - val_loss: 7.9797
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - categorical_accuracy: 0.6620 - loss: 7.6573 - val_categorical_accuracy: 0.5889 - val_loss: 7.9544
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - categorical_accuracy: 0.6627 - loss: 7.6376 - val_categorical_accuracy: 0.6000 - val_loss: 7.9921
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - categorical_accuracy: 0.6291 - loss: 7.6815 - val_categorical_accuracy: 0.5944 - val_loss: 7.8961
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - categorical_accuracy: 0.6749 - loss: 7.5913 - val_categorical_accuracy: 0.6056 - val_loss: 7.8741
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - categorical_accuracy: 0.6601 - loss: 7.5592 - val_categorical_accuracy: 0.6278 - val_loss: 7.8967
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - categorical_accuracy: 0.6617 - loss: 7.5385 - val_categorical_accuracy: 0.6111 - val_loss: 7.8334
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.6679 - loss: 7.5504 - val_categorical_accuracy: 0.6333 - val_loss: 7.8470
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.6975 - loss: 7.5103 - val_categorical_accuracy: 0.6167 - val_loss: 7.8293
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.7537 - loss: 7.3661 - val_categorical_accuracy: 0.6389 - val_loss: 7.8158
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - categorical_accuracy: 0.7601 - loss: 7.3555 - val_categorical_accuracy: 0.6222 - val_loss: 7.7749
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - categorical_accuracy: 0.7455 - loss: 7.3520 - val_categorical_accuracy: 0.6500 - val_loss: 7.8037
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - categorical_accuracy: 0.7510 - loss: 7.3978 - val_categorical_accuracy: 0.6111 - val_loss: 7.9703
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - categorical_accuracy: 0.6958 - loss: 7.5292 - val_categorical_accuracy: 0.6167 - val_loss: 7.7774
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - categorical_accuracy: 0.6974 - loss: 7.4391 - val_categorical_accuracy: 0.5889 - val_loss: 7.8532
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.7229 - loss: 7.4005 - val_categorical_accuracy: 0.6778 - val_loss: 7.6706
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - categorical_accuracy: 0.7888 - loss: 7.2941 - val_categorical_accuracy: 0.6722 - val_loss: 7.6582
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - categorical_accuracy: 0.7850 - loss: 7.2838 - val_categorical_accuracy: 0.6667 - val_loss: 7.6756
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - categorical_accuracy: 0.7624 - loss: 7.2809 - val_categorical_accuracy: 0.6778 - val_loss: 7.6140
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - categorical_accuracy: 0.7559 - loss: 7.2505 - val_categorical_accuracy: 0.6944 - val_loss: 7.5950
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - categorical_accuracy: 0.8055 - loss: 7.1906 - val_categorical_accuracy: 0.6833 - val_loss: 7.5944
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - categorical_accuracy: 0.8052 - loss: 7.1799 - val_categorical_accuracy: 0.6778 - val_loss: 7.5611
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - categorical_accuracy: 0.8005 - loss: 7.1417 - val_categorical_accuracy: 0.6778 - val_loss: 7.5514
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - categorical_accuracy: 0.8000 - loss: 7.1307 - val_categorical_accuracy: 0.6889 - val_loss: 7.5341
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - categorical_accuracy: 0.8301 - loss: 7.0839 - val_categorical_accuracy: 0.6889 - val_loss: 7.5147
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - categorical_accuracy: 0.7961 - loss: 7.0911 - val_categorical_accuracy: 0.6833 - val_loss: 7.4954
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - categorical_accuracy: 0.7507 - loss: 7.2187 - val_categorical_accuracy: 0.6611 - val_loss: 7.5858
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - categorical_accuracy: 0.8073 - loss: 7.0765 - val_categorical_accuracy: 0.6833 - val_loss: 7.4880
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - categorical_accuracy: 0.8288 - loss: 7.0299 - val_categorical_accuracy: 0.7000 - val_loss: 7.4762
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - categorical_accuracy: 0.7997 - loss: 7.1086 - val_categorical_accuracy: 0.7111 - val_loss: 7.4440
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - categorical_accuracy: 0.8268 - loss: 7.0441 - val_categorical_accuracy: 0.7278 - val_loss: 7.4107
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.8287 - loss: 7.0188 - val_categorical_accuracy: 0.7111 - val_loss: 7.4366
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - categorical_accuracy: 0.8061 - loss: 7.0735 - val_categorical_accuracy: 0.7111 - val_loss: 7.4406
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - categorical_accuracy: 0.8256 - loss: 6.9517 - val_categorical_accuracy: 0.7111 - val_loss: 7.4328
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.8341 - loss: 7.0254 - val_categorical_accuracy: 0.7278 - val_loss: 7.3552
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - categorical_accuracy: 0.8352 - loss: 6.9816 - val_categorical_accuracy: 0.7278 - val_loss: 7.3841
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - categorical_accuracy: 0.8649 - loss: 6.9082 - val_categorical_accuracy: 0.7611 - val_loss: 7.3629
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - categorical_accuracy: 0.8599 - loss: 6.8906 - val_categorical_accuracy: 0.7333 - val_loss: 7.3411
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - categorical_accuracy: 0.8695 - loss: 6.8850 - val_categorical_accuracy: 0.7389 - val_loss: 7.3600
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - categorical_accuracy: 0.8590 - loss: 6.8982 - val_categorical_accuracy: 0.7556 - val_loss: 7.3341
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - categorical_accuracy: 0.8923 - loss: 6.8069 - val_categorical_accuracy: 0.7500 - val_loss: 7.3551
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.8979 - loss: 6.7741 - val_categorical_accuracy: 0.7389 - val_loss: 7.3178
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - categorical_accuracy: 0.8467 - loss: 6.8885 - val_categorical_accuracy: 0.7278 - val_loss: 7.3313
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - categorical_accuracy: 0.8937 - loss: 6.7778 - val_categorical_accuracy: 0.7444 - val_loss: 7.3115
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - categorical_accuracy: 0.8559 - loss: 6.8197 - val_categorical_accuracy: 0.7167 - val_loss: 7.2865
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.8748 - loss: 6.7768 - val_categorical_accuracy: 0.7444 - val_loss: 7.3039
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - categorical_accuracy: 0.8463 - loss: 6.8909 - val_categorical_accuracy: 0.7333 - val_loss: 7.2872
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - categorical_accuracy: 0.8912 - loss: 6.7455 - val_categorical_accuracy: 0.7389 - val_loss: 7.2935
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.8815 - loss: 6.7264 - val_categorical_accuracy: 0.7611 - val_loss: 7.2139
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - categorical_accuracy: 0.8943 - loss: 6.6729 - val_categorical_accuracy: 0.7444 - val_loss: 7.2295
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - categorical_accuracy: 0.8848 - loss: 6.6921 - val_categorical_accuracy: 0.7500 - val_loss: 7.2099
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - categorical_accuracy: 0.8905 - loss: 6.6746 - val_categorical_accuracy: 0.7389 - val_loss: 7.2136
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - categorical_accuracy: 0.8944 - loss: 6.6107 - val_categorical_accuracy: 0.7500 - val_loss: 7.1656
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - categorical_accuracy: 0.8721 - loss: 6.6971 - val_categorical_accuracy: 0.7333 - val_loss: 7.2075
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - categorical_accuracy: 0.8815 - loss: 6.6708 - val_categorical_accuracy: 0.7278 - val_loss: 7.1937
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - categorical_accuracy: 0.8942 - loss: 6.6317 - val_categorical_accuracy: 0.7444 - val_loss: 7.1899
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - categorical_accuracy: 0.8889 - loss: 6.6457 - val_categorical_accuracy: 0.7278 - val_loss: 7.2391
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - categorical_accuracy: 0.8789 - loss: 6.6005 - val_categorical_accuracy: 0.7167 - val_loss: 7.2483
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - categorical_accuracy: 0.9121 - loss: 6.5363 - val_categorical_accuracy: 0.7556 - val_loss: 7.1568
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - categorical_accuracy: 0.9138 - loss: 6.5333 - val_categorical_accuracy: 0.7556 - val_loss: 7.1462
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - categorical_accuracy: 0.8978 - loss: 6.5620 - val_categorical_accuracy: 0.7500 - val_loss: 7.1667
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - categorical_accuracy: 0.8976 - loss: 6.5532 - val_categorical_accuracy: 0.7444 - val_loss: 7.1483
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - categorical_accuracy: 0.8901 - loss: 6.5490 - val_categorical_accuracy: 0.7389 - val_loss: 7.1720
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - categorical_accuracy: 0.8965 - loss: 6.5115 - val_categorical_accuracy: 0.7444 - val_loss: 7.1587
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - categorical_accuracy: 0.9057 - loss: 6.4852 - val_categorical_accuracy: 0.7611 - val_loss: 7.1160
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - categorical_accuracy: 0.9201 - loss: 6.4362 - val_categorical_accuracy: 0.7500 - val_loss: 7.2306
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - categorical_accuracy: 0.9132 - loss: 6.4303 - val_categorical_accuracy: 0.7444 - val_loss: 7.1874
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - categorical_accuracy: 0.9091 - loss: 6.4253 - val_categorical_accuracy: 0.7611 - val_loss: 7.1677
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - categorical_accuracy: 0.8773 - loss: 6.5024 - val_categorical_accuracy: 0.7278 - val_loss: 7.2436
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - categorical_accuracy: 0.8448 - loss: 6.5954 - val_categorical_accuracy: 0.7444 - val_loss: 7.3333
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - categorical_accuracy: 0.7520 - loss: 6.8507 - val_categorical_accuracy: 0.7222 - val_loss: 7.2643
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - categorical_accuracy: 0.8277 - loss: 6.6741 - val_categorical_accuracy: 0.6833 - val_loss: 7.1590
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.8515 - loss: 6.5856 - val_categorical_accuracy: 0.7500 - val_loss: 7.1360
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - categorical_accuracy: 0.8887 - loss: 6.5732 - val_categorical_accuracy: 0.7056 - val_loss: 7.1573
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - categorical_accuracy: 0.8159 - loss: 6.7407 - val_categorical_accuracy: 0.7000 - val_loss: 7.1720
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.8194 - loss: 6.6146 - val_categorical_accuracy: 0.7111 - val_loss: 7.0028
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - categorical_accuracy: 0.8639 - loss: 6.6105 - val_categorical_accuracy: 0.7444 - val_loss: 7.1408
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - categorical_accuracy: 0.8667 - loss: 6.4753 - val_categorical_accuracy: 0.7889 - val_loss: 6.9019
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - categorical_accuracy: 0.9002 - loss: 6.4214 - val_categorical_accuracy: 0.7778 - val_loss: 6.8514
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - categorical_accuracy: 0.9087 - loss: 6.4076 - val_categorical_accuracy: 0.7889 - val_loss: 6.8831
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - categorical_accuracy: 0.9420 - loss: 6.3005 - val_categorical_accuracy: 0.7722 - val_loss: 6.9859
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - categorical_accuracy: 0.9109 - loss: 6.3334 - val_categorical_accuracy: 0.7889 - val_loss: 6.9625
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - categorical_accuracy: 0.9240 - loss: 6.3296 - val_categorical_accuracy: 0.7889 - val_loss: 6.9314
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - categorical_accuracy: 0.9219 - loss: 6.3339 - val_categorical_accuracy: 0.7611 - val_loss: 6.9538
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - categorical_accuracy: 0.9515 - loss: 6.2260 - val_categorical_accuracy: 0.7500 - val_loss: 7.0012
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - categorical_accuracy: 0.9347 - loss: 6.2516 - val_categorical_accuracy: 0.7667 - val_loss: 7.0174
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - categorical_accuracy: 0.9376 - loss: 6.2392 - val_categorical_accuracy: 0.7778 - val_loss: 6.9821
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - categorical_accuracy: 0.9289 - loss: 6.2522 - val_categorical_accuracy: 0.7667 - val_loss: 7.0210
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - categorical_accuracy: 0.9359 - loss: 6.2524 - val_categorical_accuracy: 0.7722 - val_loss: 7.0562
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - categorical_accuracy: 0.8853 - loss: 6.3566 - val_categorical_accuracy: 0.7500 - val_loss: 6.9693
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - categorical_accuracy: 0.9110 - loss: 6.2852 - val_categorical_accuracy: 0.7833 - val_loss: 6.9294
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - categorical_accuracy: 0.9335 - loss: 6.2364 - val_categorical_accuracy: 0.7889 - val_loss: 6.9412
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.9386 - loss: 6.2025 - val_categorical_accuracy: 0.7778 - val_loss: 6.9896
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - categorical_accuracy: 0.9520 - loss: 6.1443 - val_categorical_accuracy: 0.7833 - val_loss: 6.9704
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - categorical_accuracy: 0.9413 - loss: 6.2139 - val_categorical_accuracy: 0.7611 - val_loss: 7.0395
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - categorical_accuracy: 0.9445 - loss: 6.1953 - val_categorical_accuracy: 0.7889 - val_loss: 6.9073
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - categorical_accuracy: 0.9470 - loss: 6.1336 - val_categorical_accuracy: 0.7889 - val_loss: 7.0013
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - categorical_accuracy: 0.9297 - loss: 6.1848 - val_categorical_accuracy: 0.7944 - val_loss: 6.9731
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - categorical_accuracy: 0.9382 - loss: 6.1460 - val_categorical_accuracy: 0.7944 - val_loss: 6.9636

# %% [markdown]
# ## Plot training history

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Make Prediction

# %%
res = model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step

# %%
X_train.shape
# Out:
# (420, 30, 1518)

# %%
y_test.shape
# Out:
# (180, 15)

# %%
actions[np.argmax(res[0])]
# Out:
# np.str_('bibi')

# %%
actions[np.argmax(y_test[0])]
# Out:
# np.str_('yego')

# %% [markdown]
# # Save weights

# %%
# Saving the weights

model.save('RSL Action Detection Script_phase3.h5')

# deleting the model del model
# loading the model model.load_weights('action.h5') after rebuilding and compailing no training
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
