# %% [markdown]
# # 1. Improt  and Install Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import  mediapipe  as mp

# %% [markdown]
# # 2. Keypoint using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic Model
mp_drawing  = mp.solutions.drawing_utils # Drawing utilities

# %%
def  mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB) #converting color
    image.flags.writeable = False # Image is no longer writeable
    results = model.process(image) #make prediction
    image.flags.writeable = True # Image is now writeable
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR) #converting color
    return image,results

# %% [markdown]
# # This is optional now,The one being used is the draw_styled_landmarks.

# %%
def draw_styled_landmarks(image, result):
    mp_drawing.draw_landmarks(image,result.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(250,250,250), thickness = 2, circle_radius = 2),
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness = 1, circle_radius = 1)) # Draw pose conections
    mp_drawing.draw_landmarks(image,result.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS) # Draw left Hand conections
    mp_drawing.draw_landmarks(image,result.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS) # Draw Right Hand conection.

# %% [markdown]
# # Optional {For testing the camera and detection mechanisim}

# %%
cap  = cv2.VideoCapture(1)
# Accessing mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence = 0.5) as holistic:
    while cap.isOpened():
        
        # Read feed
        ret,frame = cap.read()

        # Make detection
        image, results = mediapipe_detection(frame,holistic)
        
        
        # Draw  landmarks
        draw_styled_landmarks(image,results)
        

        cv2.imshow('RSL Feed', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
# With out Face points  multiple left and hand cordinates to increase accuracy
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    # magnifiying the hands value for better accuracy
    return np.concatenate([pose, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
#output will be  arrray containing numerical values for the extracted keypoints
DATA_PATH = os.path.join('MP_Data_phase_3') #exported data

#action we try to detect 

# action that we want to detect Yego 


actions = np.array(['---','yego', 'Neza','Bibi','Urakoze', 'Isibo', 'Umurenge', 'Igihugu', 'Umujyi wa Kigali', 'Kicukiro', 'Nyarugenge'])
no_sequences = 50 # number of videos
start_folder = 1
sequence_length = 30 # frames to be used

# %%
for action in actions:
    for sequence in range(start_folder, start_folder+no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH,action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
#######################################################
#This saves both the extracted features and the video#
#######################################################


# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'MP4V')


cap = cv2.VideoCapture(1)


# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.4, min_tracking_confidence=0.4) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            #########################################################
            output_file = os.path.join(DATA_PATH, action, str(sequence), "{}_video_{}.mp4".format(action,sequence))
            out = cv2.VideoWriter(output_file, fourcc, 30.0, (640, 480), isColor=True)
            # Set the bitrate (optional)
            bitrate = 4000000
            out.set(cv2.CAP_PROP_BITRATE, bitrate)
            #########################################################
            
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()
                
                
                ##############################################
                ret, frame = cap.read()

                if ret:
                    # Write the frame into the video file
                    out.write(frame)
                ##############################################    
                

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING  COLLECTION', (15,40),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,255,0), 1, cv2.LINE_AA)
                    cv2.putText(image,'Collection frames for  {} video number {}'.format(action,sequence),(15,20),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('RSL Data Collection Feed', image)
                    cv2.waitKey(2000)
                else:       
                    cv2.putText(image,'Collection frames for  {} video number {}'.format(action,sequence),(15,20),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('RSL Data Collection Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for  num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'---': 0,
#  'yego': 1,
#  'Neza': 2,
#  'Bibi': 3,
#  'Urakoze': 4,
#  'Isibo': 5,
#  'Umurenge': 6,
#  'Igihugu': 7,
#  'Umujyi wa Kigali': 8,
#  'Kicukiro': 9,
#  'Nyarugenge': 10}

# %%
#pre_processing values
sequences, labels = [], []
for action in actions:
    for sequence in range(1,no_sequences+1):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (550, 30, 1392)

# %%
np.array(labels).shape
# Out:
# (550,)

# %%
#conversion to get something we can use with

# x representing sequence in numpy_array form 

x = np.array(sequences)


x.shape
# Out:
# (550, 30, 1392)

# %%
# y representing labels converting it them to  using  to_categorical function 

y = to_categorical(labels).astype(int)

y.shape
# Out:
# (550, 11)

# %%
#train and test partition

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
x_train.shape
# Out:
# (385, 30, 1392)

# %%
y_test.shape
# Out:
# (165, 11)

# %% [markdown]
# # 7. Building and Training LSTM Neural Network
# ### Be using Keras

# %%
#import key dependenceies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from keras import regularizers

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir = log_dir)

# %%
opt = Adam(learning_rate=0.00001)

#setting up a neural network Architecture
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu',kernel_regularizer=regularizers.l2(0.01), input_shape=(30,1392)))
model.add(LSTM(128, return_sequences=True, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(LSTM(64, return_sequences=False, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(actions.shape[0], activation='softmax', kernel_regularizer=regularizers.l2(0.01)))

# %%
# Compiling the model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(x_train, y_train, epochs=180, callbacks=[tb_callback])
# Out:
# Epoch 1/180
# 13/13 [==============================] - 3s 55ms/step - loss: 10.8042 - categorical_accuracy: 0.0909
# Epoch 2/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.7640 - categorical_accuracy: 0.0909
# Epoch 3/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.7254 - categorical_accuracy: 0.0987
# Epoch 4/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.6882 - categorical_accuracy: 0.1429
# Epoch 5/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.6515 - categorical_accuracy: 0.1584
# Epoch 6/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.6152 - categorical_accuracy: 0.1740
# Epoch 7/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.5790 - categorical_accuracy: 0.1740
# Epoch 8/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.5429 - categorical_accuracy: 0.1896
# Epoch 9/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.5063 - categorical_accuracy: 0.1896
# Epoch 10/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.4698 - categorical_accuracy: 0.2026
# Epoch 11/180
# 13/13 [==============================] - 1s 52ms/step - loss: 10.4331 - categorical_accuracy: 0.2130
# Epoch 12/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.3964 - categorical_accuracy: 0.2519
# Epoch 13/180
# 13/13 [==============================] - 1s 55ms/step - loss: 10.3585 - categorical_accuracy: 0.2623
# Epoch 14/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.3232 - categorical_accuracy: 0.2987
# Epoch 15/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.2843 - categorical_accuracy: 0.3584
# Epoch 16/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.2429 - categorical_accuracy: 0.3636
# Epoch 17/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.2004 - categorical_accuracy: 0.3714
# Epoch 18/180
# 13/13 [==============================] - 1s 53ms/step - loss: 10.1564 - categorical_accuracy: 0.4675
# Epoch 19/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.1049 - categorical_accuracy: 0.4286
# Epoch 20/180
# 13/13 [==============================] - 1s 54ms/step - loss: 10.0472 - categorical_accuracy: 0.4104
# Epoch 21/180
# 13/13 [==============================] - 1s 53ms/step - loss: 9.9752 - categorical_accuracy: 0.3429
# Epoch 22/180
# 13/13 [==============================] - 1s 53ms/step - loss: 9.8592 - categorical_accuracy: 0.4026
# Epoch 23/180
# 13/13 [==============================] - 1s 53ms/step - loss: 9.7220 - categorical_accuracy: 0.3922
# Epoch 24/180
# 13/13 [==============================] - 1s 54ms/step - loss: 9.6082 - categorical_accuracy: 0.3922
# Epoch 25/180
# 13/13 [==============================] - 1s 54ms/step - loss: 9.4816 - categorical_accuracy: 0.4260
# Epoch 26/180
# 13/13 [==============================] - 1s 64ms/step - loss: 9.3841 - categorical_accuracy: 0.4286
# Epoch 27/180
# 13/13 [==============================] - 1s 66ms/step - loss: 9.2694 - categorical_accuracy: 0.4987
# Epoch 28/180
# 13/13 [==============================] - 1s 67ms/step - loss: 9.1924 - categorical_accuracy: 0.5455
# Epoch 29/180
# 13/13 [==============================] - 1s 67ms/step - loss: 9.1196 - categorical_accuracy: 0.5506
# Epoch 30/180
# 13/13 [==============================] - 1s 65ms/step - loss: 9.0602 - categorical_accuracy: 0.5584
# Epoch 31/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.9557 - categorical_accuracy: 0.5870
# Epoch 32/180
# 13/13 [==============================] - 1s 67ms/step - loss: 8.9222 - categorical_accuracy: 0.6000
# Epoch 33/180
# 13/13 [==============================] - 1s 66ms/step - loss: 8.8130 - categorical_accuracy: 0.6078
# Epoch 34/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.7189 - categorical_accuracy: 0.6545
# Epoch 35/180
# 13/13 [==============================] - 1s 66ms/step - loss: 8.6875 - categorical_accuracy: 0.6961
# Epoch 36/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.6068 - categorical_accuracy: 0.7273
# Epoch 37/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.5436 - categorical_accuracy: 0.7688
# Epoch 38/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.5289 - categorical_accuracy: 0.7247
# Epoch 39/180
# 13/13 [==============================] - 1s 66ms/step - loss: 8.4467 - categorical_accuracy: 0.7792
# Epoch 40/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.4032 - categorical_accuracy: 0.7974
# Epoch 41/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.2990 - categorical_accuracy: 0.8104
# Epoch 42/180
# 13/13 [==============================] - 1s 68ms/step - loss: 8.2967 - categorical_accuracy: 0.7870
# Epoch 43/180
# 13/13 [==============================] - 1s 66ms/step - loss: 8.1581 - categorical_accuracy: 0.8597
# Epoch 44/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.1298 - categorical_accuracy: 0.8416
# Epoch 45/180
# 13/13 [==============================] - 1s 65ms/step - loss: 8.0133 - categorical_accuracy: 0.8623
# Epoch 46/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.9398 - categorical_accuracy: 0.8805
# Epoch 47/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.8876 - categorical_accuracy: 0.8883
# Epoch 48/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.9103 - categorical_accuracy: 0.8571
# Epoch 49/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.8451 - categorical_accuracy: 0.8831
# Epoch 50/180
# 13/13 [==============================] - 1s 66ms/step - loss: 8.1174 - categorical_accuracy: 0.7948
# Epoch 51/180
# 13/13 [==============================] - 1s 67ms/step - loss: 8.0043 - categorical_accuracy: 0.8156
# Epoch 52/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.8178 - categorical_accuracy: 0.8831
# Epoch 53/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.7119 - categorical_accuracy: 0.9065
# Epoch 54/180
# 13/13 [==============================] - 1s 71ms/step - loss: 7.6729 - categorical_accuracy: 0.9065
# Epoch 55/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.6633 - categorical_accuracy: 0.8961
# Epoch 56/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.6472 - categorical_accuracy: 0.8935
# Epoch 57/180
# 13/13 [==============================] - 1s 66ms/step - loss: 7.5990 - categorical_accuracy: 0.9013
# Epoch 58/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.5767 - categorical_accuracy: 0.8987
# Epoch 59/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.5337 - categorical_accuracy: 0.9091
# Epoch 60/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.5078 - categorical_accuracy: 0.9091
# Epoch 61/180
# 13/13 [==============================] - 1s 66ms/step - loss: 7.4835 - categorical_accuracy: 0.9091
# Epoch 62/180
# 13/13 [==============================] - 1s 67ms/step - loss: 7.4611 - categorical_accuracy: 0.9091
# Epoch 63/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.4428 - categorical_accuracy: 0.9091
# Epoch 64/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.4281 - categorical_accuracy: 0.9039
# Epoch 65/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.3904 - categorical_accuracy: 0.9091
# Epoch 66/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.3855 - categorical_accuracy: 0.8987
# Epoch 67/180
# 13/13 [==============================] - 1s 66ms/step - loss: 7.3414 - categorical_accuracy: 0.9091
# Epoch 68/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.3393 - categorical_accuracy: 0.9039
# Epoch 69/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.2989 - categorical_accuracy: 0.9065
# Epoch 70/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.2567 - categorical_accuracy: 0.9091
# Epoch 71/180
# 13/13 [==============================] - 1s 65ms/step - loss: 7.2152 - categorical_accuracy: 0.9169
# Epoch 72/180
# 13/13 [==============================] - 1s 67ms/step - loss: 7.1747 - categorical_accuracy: 0.9143
# Epoch 73/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.3284 - categorical_accuracy: 0.8779
# Epoch 74/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.4609 - categorical_accuracy: 0.8104
# Epoch 75/180
# 13/13 [==============================] - 1s 63ms/step - loss: 7.2065 - categorical_accuracy: 0.8857
# Epoch 76/180
# 13/13 [==============================] - 1s 66ms/step - loss: 7.1336 - categorical_accuracy: 0.9117
# Epoch 77/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.0844 - categorical_accuracy: 0.9429
# Epoch 78/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.0622 - categorical_accuracy: 0.9429
# Epoch 79/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.0383 - categorical_accuracy: 0.9455
# Epoch 80/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.0112 - categorical_accuracy: 0.9506
# Epoch 81/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.9934 - categorical_accuracy: 0.9558
# Epoch 82/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.9743 - categorical_accuracy: 0.9610
# Epoch 83/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.9562 - categorical_accuracy: 0.9636
# Epoch 84/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.9398 - categorical_accuracy: 0.9714
# Epoch 85/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.9234 - categorical_accuracy: 0.9714
# Epoch 86/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.9060 - categorical_accuracy: 0.9766
# Epoch 87/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.8921 - categorical_accuracy: 0.9740
# Epoch 88/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.8749 - categorical_accuracy: 0.9818
# Epoch 89/180
# 13/13 [==============================] - 1s 63ms/step - loss: 6.8577 - categorical_accuracy: 0.9792
# Epoch 90/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.8349 - categorical_accuracy: 0.9818
# Epoch 91/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.8210 - categorical_accuracy: 0.9844
# Epoch 92/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.1564 - categorical_accuracy: 0.9013
# Epoch 93/180
# 13/13 [==============================] - 1s 64ms/step - loss: 7.1351 - categorical_accuracy: 0.8416
# Epoch 94/180
# 13/13 [==============================] - 1s 66ms/step - loss: 7.0959 - categorical_accuracy: 0.9143
# Epoch 95/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.8757 - categorical_accuracy: 0.9766
# Epoch 96/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.8736 - categorical_accuracy: 0.9662
# Epoch 97/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.7904 - categorical_accuracy: 0.9714
# Epoch 98/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.7594 - categorical_accuracy: 0.9844
# Epoch 99/180
# 13/13 [==============================] - 1s 63ms/step - loss: 6.7395 - categorical_accuracy: 0.9896
# Epoch 100/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.7193 - categorical_accuracy: 0.9922
# Epoch 101/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.7508 - categorical_accuracy: 0.9766
# Epoch 102/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.6995 - categorical_accuracy: 0.9844
# Epoch 103/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.6692 - categorical_accuracy: 0.9922
# Epoch 104/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.6527 - categorical_accuracy: 0.9948
# Epoch 105/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.6374 - categorical_accuracy: 0.9974
# Epoch 106/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.6222 - categorical_accuracy: 0.9974
# Epoch 107/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.6077 - categorical_accuracy: 1.0000
# Epoch 108/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.5931 - categorical_accuracy: 1.0000
# Epoch 109/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.5805 - categorical_accuracy: 1.0000
# Epoch 110/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.5655 - categorical_accuracy: 1.0000
# Epoch 111/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.5540 - categorical_accuracy: 1.0000
# Epoch 112/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.5389 - categorical_accuracy: 1.0000
# Epoch 113/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.5258 - categorical_accuracy: 1.0000
# Epoch 114/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.5132 - categorical_accuracy: 1.0000
# Epoch 115/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.5007 - categorical_accuracy: 1.0000
# Epoch 116/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.4883 - categorical_accuracy: 1.0000
# Epoch 117/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.4762 - categorical_accuracy: 1.0000
# Epoch 118/180
# 13/13 [==============================] - 1s 70ms/step - loss: 6.4641 - categorical_accuracy: 1.0000
# Epoch 119/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.4523 - categorical_accuracy: 1.0000
# Epoch 120/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.4405 - categorical_accuracy: 1.0000
# Epoch 121/180
# 13/13 [==============================] - 1s 70ms/step - loss: 6.4287 - categorical_accuracy: 1.0000
# Epoch 122/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.4170 - categorical_accuracy: 1.0000
# Epoch 123/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.4055 - categorical_accuracy: 1.0000
# Epoch 124/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3941 - categorical_accuracy: 1.0000
# Epoch 125/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3828 - categorical_accuracy: 1.0000
# Epoch 126/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3715 - categorical_accuracy: 1.0000
# Epoch 127/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3601 - categorical_accuracy: 1.0000
# Epoch 128/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3489 - categorical_accuracy: 1.0000
# Epoch 129/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3377 - categorical_accuracy: 1.0000
# Epoch 130/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.3361 - categorical_accuracy: 0.9974
# Epoch 131/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.3207 - categorical_accuracy: 1.0000
# Epoch 132/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3140 - categorical_accuracy: 1.0000
# Epoch 133/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.3060 - categorical_accuracy: 0.9974
# Epoch 134/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.5103 - categorical_accuracy: 0.9532
# Epoch 135/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.8216 - categorical_accuracy: 0.8727
# Epoch 136/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.4661 - categorical_accuracy: 0.9299
# Epoch 137/180
# 13/13 [==============================] - 1s 72ms/step - loss: 6.3159 - categorical_accuracy: 0.9818
# Epoch 138/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.3168 - categorical_accuracy: 0.9844
# Epoch 139/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.3320 - categorical_accuracy: 0.9662
# Epoch 140/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.2589 - categorical_accuracy: 0.9948
# Epoch 141/180
# 13/13 [==============================] - 1s 73ms/step - loss: 6.2364 - categorical_accuracy: 0.9974
# Epoch 142/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.2271 - categorical_accuracy: 0.9948
# Epoch 143/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.2112 - categorical_accuracy: 1.0000
# Epoch 144/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.2008 - categorical_accuracy: 1.0000
# Epoch 145/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.1903 - categorical_accuracy: 1.0000
# Epoch 146/180
# 13/13 [==============================] - 1s 65ms/step - loss: 6.1799 - categorical_accuracy: 1.0000
# Epoch 147/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1702 - categorical_accuracy: 1.0000
# Epoch 148/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1606 - categorical_accuracy: 1.0000
# Epoch 149/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1511 - categorical_accuracy: 1.0000
# Epoch 150/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1415 - categorical_accuracy: 1.0000
# Epoch 151/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1321 - categorical_accuracy: 1.0000
# Epoch 152/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1227 - categorical_accuracy: 1.0000
# Epoch 153/180
# 13/13 [==============================] - 1s 70ms/step - loss: 6.1135 - categorical_accuracy: 1.0000
# Epoch 154/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.1044 - categorical_accuracy: 1.0000
# Epoch 155/180
# 13/13 [==============================] - 1s 67ms/step - loss: 6.0953 - categorical_accuracy: 1.0000
# Epoch 156/180
# 13/13 [==============================] - 1s 70ms/step - loss: 6.0862 - categorical_accuracy: 1.0000
# Epoch 157/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.0772 - categorical_accuracy: 1.0000
# Epoch 158/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.0682 - categorical_accuracy: 1.0000
# Epoch 159/180
# 13/13 [==============================] - 1s 66ms/step - loss: 6.0591 - categorical_accuracy: 1.0000
# Epoch 160/180
# 13/13 [==============================] - 1s 69ms/step - loss: 6.0502 - categorical_accuracy: 1.0000
# Epoch 161/180
# 13/13 [==============================] - 1s 68ms/step - loss: 6.0412 - categorical_accuracy: 1.0000
# Epoch 162/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.0324 - categorical_accuracy: 1.0000
# Epoch 163/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.0235 - categorical_accuracy: 1.0000
# Epoch 164/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.0146 - categorical_accuracy: 1.0000
# Epoch 165/180
# 13/13 [==============================] - 1s 64ms/step - loss: 6.0059 - categorical_accuracy: 1.0000
# Epoch 166/180
# 13/13 [==============================] - 1s 64ms/step - loss: 5.9970 - categorical_accuracy: 1.0000
# Epoch 167/180
# 13/13 [==============================] - 1s 65ms/step - loss: 5.9881 - categorical_accuracy: 1.0000
# Epoch 168/180
# 13/13 [==============================] - 1s 65ms/step - loss: 5.9791 - categorical_accuracy: 1.0000
# Epoch 169/180
# 13/13 [==============================] - 1s 66ms/step - loss: 5.9702 - categorical_accuracy: 1.0000
# Epoch 170/180
# 13/13 [==============================] - 1s 64ms/step - loss: 5.9614 - categorical_accuracy: 1.0000
# Epoch 171/180
# 13/13 [==============================] - 1s 64ms/step - loss: 5.9527 - categorical_accuracy: 1.0000
# Epoch 172/180
# 13/13 [==============================] - 1s 67ms/step - loss: 5.9439 - categorical_accuracy: 1.0000
# Epoch 173/180
# 13/13 [==============================] - 1s 68ms/step - loss: 5.9352 - categorical_accuracy: 1.0000
# Epoch 174/180
# 13/13 [==============================] - 1s 65ms/step - loss: 5.9265 - categorical_accuracy: 1.0000
# Epoch 175/180
# 13/13 [==============================] - 1s 66ms/step - loss: 5.9178 - categorical_accuracy: 1.0000
# Epoch 176/180
# 13/13 [==============================] - 1s 67ms/step - loss: 5.9091 - categorical_accuracy: 1.0000
# Epoch 177/180
# 13/13 [==============================] - 1s 66ms/step - loss: 5.9005 - categorical_accuracy: 1.0000
# Epoch 178/180
# 13/13 [==============================] - 1s 65ms/step - loss: 5.8918 - categorical_accuracy: 1.0000
# Epoch 179/180
# 13/13 [==============================] - 1s 65ms/step - loss: 5.8832 - categorical_accuracy: 1.0000
# Epoch 180/180
# 13/13 [==============================] - 1s 64ms/step - loss: 5.8746 - categorical_accuracy: 1.0000

# %%
model.summary() #get the summary of the training process
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 30, 64)            372992
#
#  lstm_7 (LSTM)               (None, 30, 128)           98816
#
#  lstm_8 (LSTM)               (None, 64)                49408
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 11)                363
#
# =================================================================
# Total params: 527,819
# Trainable params: 527,819
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #  8. Make Prediction

# %%
res = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 16ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'Nyarugenge'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'Nyarugenge'

# %% [markdown]
# #  9. Save Weights

# %%
# Saving the weights

model.save('RSL Action Detection Script_phase3.h5')

# deleting the model del model
# loading the model model.load_weights('action.h5') after rebuilding and compailing no training

# %% [markdown]
# # 10 . Evaluation Using Confusion Matrix and Accuracy

# %%
from  sklearn.metrics import multilabel_confusion_matrix,accuracy_score

# %%
yhat = model.predict(x_train)
# Out:
# 13/13 [==============================] - 0s 18ms/step

# %%
ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue,yhat)
# Out:
# array([[[350,   0],
#         [  0,  35]],
#
#        [[348,   0],
#         [  0,  37]],
#
#        [[346,   0],
#         [  0,  39]],
#
#        [[347,   0],
#         [  0,  38]],
#
#        [[353,   0],
#         [  0,  32]],
#
#        [[356,   0],
#         [  0,  29]],
#
#        [[343,   0],
#         [  0,  42]],
#
#        [[351,   0],
#         [  0,  34]],
#
#        [[353,   0],
#         [  0,  32]],
#
#        [[352,   0],
#         [  0,  33]],
#
#        [[351,   0],
#         [  0,  34]]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# Obtain the confusion matrix
cm = confusion_matrix(ytrue, yhat)

# Normalize the confusion matrix
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
# Define the labels
class_names = actions

# %%
import matplotlib.pyplot as plt

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))
im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.cm.Blues, vmin=0, vmax=1)
ax.set(xticks=np.arange(cm_norm.shape[1]),
       yticks=np.arange(cm_norm.shape[0]),
       xticklabels=class_names,
       yticklabels=class_names,
       xlabel='Predicted label',
       ylabel='True label')

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        ax.text(j, i, format(cm_norm[i, j], '.2f'),
                ha="center", va="center",
                color="white" if cm_norm[i, j] > 0.5 else "black")

# Add a colorbar
fig.colorbar(im, ax=ax)
plt.show()

# %%
accuracy_score(ytrue,yhat)
# Out:
# 1.0

# %%
res.size
# Out:
# 1815

# %%
res.shape
# Out:
# (165, 11)

# %%
np.argmax(res)
# Out:
# 33

# %% [markdown]
# # 11.  Test in Real Time

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.85
init_time = time.time()

cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                       
                    else:
                        sentence.append(actions[np.argmax(res)])
#             else: #clearing
#                 if time.time() - init_time > 15:
#                     print ('its time to clear')
#                     init_time = time.time()
#                     sentence.clear()

            if len(sentence) > 8: 
                sentence = sentence[-8:]

 
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)

        
        # Show to screen
        cv2.imshow('RSL Translation Feed', image)
        
        # clear the sentence gracefully
        if cv2.waitKey(10) & 0xFF == ord('c'):
            sentence.clear()

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
cap.release()
cv2.destroyAllWindows()
